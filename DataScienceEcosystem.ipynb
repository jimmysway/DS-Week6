# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
#
# ![2-title.png](attachment:ee218c7d-fc70-4638-b4a7-1b330a46494f.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# ![3-intro.png](attachment:3442b293-afe3-42c0-8a1e-fa0c5790bbbf.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. C++
# 4. Java
#
# ![4-dslanguages.png](attachment:7c68ff6f-b3d9-425e-ad02-0a778020fb37.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. matplotlib
# 2. pandas
# 3. numpy
# 4. scipy
#
# ![5-dslibraries.png](attachment:4ee5722b-0a02-4d48-80d7-32f30f747ff7.png)

# %% [markdown]
# | Data Science Tools |
# -
# | Jupyter Notebooks |
# | Spyder |
# | Apache Spark |
#
# ![6-dstools.png](attachment:6322f4a3-f50e-459f-8e84-4c11e07e2346.png)

# %% [markdown]
# ### Below are a few examples of evaluation arithmetic expressions in Python
#
# ![7-introarithmetic.png](attachment:47019af6-8db0-40a1-9bfb-1602d2bae690.png)

# %%
print((3*4)+5)

#This is a simple arithmetic expression to multiply then add integers
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:587e99c2-79f6-4691-80a4-cb77abc77a02.png)

# %%
minutes = input("Insert Minutes: ")
#This will convert 200 minutes to hours by diving by 60
hours = minutes/60
print(hours)

# %% [markdown]
# ![9-hourstominutes.png](attachment:6f4f1b90-dd31-4fbc-be43-df1472b130ec.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List popular libraries for Data Science
# - List popular development environments for Data Science
#
# ![10-objectives.png](attachment:8961dac3-3a8b-42fb-8e9b-6570950ae0d1.png)

# %% [markdown]
# ## Author
# J. Sui
#
# ![11-authordetails.png](attachment:5e178933-6d85-448e-8b8c-7f202c3537d7.png)
